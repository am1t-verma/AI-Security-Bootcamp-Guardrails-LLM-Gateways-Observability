# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    model_provider = "ollama",
    model = "qwen2.5:3b"
    )

# %%
model
# Out:
# ChatOllama(metadata={'lc_versions': {'langchain-core': '1.6.4', 'langchain': '1.4.2'}}, model='qwen2.5:3b')

# %%
# invoke the model
response = model.invoke("hello!")
print(response)
# Out:
# content='Hello! How can I assist you today?' additional_kwargs={} response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-09-24T10:07:46.725105Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2583862833, 'load_duration': 2073891625, 'prompt_eval_count': 31, 'prompt_eval_duration': 158538000, 'eval_count': 10, 'eval_duration': 343272000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'} id='lc_run--01a0d2e2-a60a-7693-ab4f-527451c21d62-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 31, 'output_tokens': 10, 'total_tokens': 41}

# %%
response.content
# Out:
# 'Hello! How can I assist you today?'

# %%
# anothe diff method !
from langchain_ollama import ChatOllama
model = ChatOllama(model = "qwen2.5:3b")
model.invoke("hello")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={}, response_metadata={'model': 'qwen2.5:3b', 'created_at': '2026-09-24T10:10:14.049366Z', 'done': True, 'done_reason': 'stop', 'total_duration': 601434709, 'load_duration': 5539792, 'prompt_eval_count': 30, 'prompt_eval_duration': 227330000, 'eval_count': 10, 'eval_duration': 335225000, 'logprobs': None, 'model_name': 'qwen2.5:3b', 'model_provider': 'ollama'}, id='lc_run--01a0d2e4-ed46-7752-89e7-89363906a5bb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 10, 'total_tokens': 40})

# %% [markdown]
# ## **Same kind you call the OpenAi, Anthropic, AWS ... Models**
